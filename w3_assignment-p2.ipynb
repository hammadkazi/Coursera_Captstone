# %%
import pandas as pd

tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
postcode_temp=tables[0]
postcode=postcode_temp[postcode_temp.Borough != 'Not assigned']
postcode.reset_index(inplace = True, drop=True)
postcode.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# !pip install geopy
from geopy.geocoders import Nominatim
# Out:
# Requirement already satisfied: geopy in c:\users\hamma\anaconda3\lib\site-packages (1.22.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\hamma\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
postcode[['Postal Code']]
# Out:
#     Postal Code
# 0           M3A
# 1           M4A
# 2           M5A
# 3           M6A
# 4           M7A
# 5           M9A
# 6           M1B
# 7           M3B
# 8           M4B
# 9           M5B
# 10          M6B
# 11          M9B
# 12          M1C
# 13          M3C
# 14          M4C
# 15          M5C
# 16          M6C
# 17          M9C
# 18          M1E
# 19          M4E
# 20          M5E
# 21          M6E
# 22          M1G
# 23          M4G
# 24          M5G
# 25          M6G
# 26          M1H
# 27          M2H
# 28          M3H
# 29          M4H
# ..          ...
# 73          M4R
# 74          M5R
# 75          M6R
# 76          M7R
# 77          M9R
# 78          M1S
# 79          M4S
# 80          M5S
# 81          M6S
# 82          M1T
# 83          M4T
# 84          M5T
# 85          M1V
# 86          M4V
# 87          M5V
# 88          M8V
# 89          M9V
# 90          M1W
# 91          M4W
# 92          M5W
# 93          M8W
# 94          M9W
# 95          M1X
# 96          M4X
# 97          M5X
# 98          M8X
# 99          M4Y
# 100         M7Y
# 101         M8Y
# 102         M8Z
#
# [103 rows x 1 columns]
